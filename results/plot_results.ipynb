# %% [markdown]
# # Import libraries

# %%
# Load the Pandas libraries with alias 'pd' 
import pandas as pd 

# load plot library
import plotly.graph_objects as go

# %% [markdown]
# # Inception results

# %%
inception_adam = pd.read_csv("./transfer_learning_deepCNN/inception_v3/training_progress_100epochs_inception_adam_unfrozen_full_aug.csv")
inception_nadam = pd.read_csv("./transfer_learning_deepCNN/inception_v3/training_progress_100epochs_inception_nadam_unfrozen_full_aug.csv") 
inception_adagrad = pd.read_csv("./transfer_learning_deepCNN/inception_v3/training_progress_100epochs_inception_adagrad_unfrozen_full_aug.csv") 
inception_SGD = pd.read_csv("./transfer_learning_deepCNN/inception_v3/training_progress_100epochs_inception_SGD_unfrozen_full_aug.csv") 
inception_Adadelta = pd.read_csv("./transfer_learning_deepCNN/inception_v3/training_progress_100epochs_inception_Adadelta_unfrozen_full_aug.csv")

# %%
import plotly.graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=inception_adam["epoch"], y=inception_adam["val_accuracy"],
                    mode='lines',
                    name='Adam'))
fig.add_trace(go.Scatter(x=inception_nadam["epoch"], y=inception_nadam["val_accuracy"],
                    mode='lines',
                    name='Nadam'))
fig.add_trace(go.Scatter(x=inception_adagrad["epoch"], y=inception_adagrad["val_accuracy"],
                    mode='lines',
                    name='Adagrad'))
fig.add_trace(go.Scatter(x=inception_SGD["epoch"], y=inception_SGD["val_accuracy"],
                    mode='lines',
                    name='SGD'))
fig.add_trace(go.Scatter(x=inception_Adadelta["epoch"], y=inception_Adadelta["val_accuracy"],
                    mode='lines',
                    name='Adadelta'))

fig.update_yaxes(range=[0, 1.05])
fig.update_layout(xaxis_showgrid=True, yaxis_showgrid=True)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='Gray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='Gray')




fig.update_layout(
                  xaxis = dict(title = 'Epoch'),
                  yaxis = dict(title = 'Validation accuracy'),
                  title={
                    'text': "Validation accuracy for different architectures",
                    'y':0.9,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    paper_bgcolor='rgba(255,255,255, 125)',
                    plot_bgcolor='rgba(250,250,250, 125)'
                  )
fig.update_layout(legend_title='<b> Optimizer: </b>')
fig.update_layout(legend=dict(x=0.5, y=1.15))

fig.update_layout(
    title={
        'text': "<b>Validation accuracy - Inception V3</b>",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.update_layout(
    legend=dict(orientation='h',yanchor='top',xanchor='center',
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
        bgcolor="white",
        bordercolor="Black",
        borderwidth=1
    )
)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True)


fig.show()
# Out:
# <div>
#
#
#             <div id="4ceec5cc-d7ce-4054-bf31-f5b523ee63f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4ceec5cc-d7ce-4054-bf31-f5b523ee63f3")) {
#                     Plotly.newPlot(
#                         '4ceec5cc-d7ce-4054-bf31-f5b523ee63f3',
# ...

# %% [markdown]
# # MobileNet results

# %%
mobileNet_adagrad = pd.read_csv("./transfer_learning_deepCNN/mobilenet_v2/training_progress_100epochs_adagrad_frozen_full_aug.csv") 
mobileNet_adam = pd.read_csv("./transfer_learning_deepCNN/mobilenet_v2/training_progress_100epochs_adam_frozen_full_aug.csv") 
mobileNet_adam_unfrozen = pd.read_csv("./transfer_learning_deepCNN/mobilenet_v2/training_progress_100epochs_adam_unfrozen_full_aug.csv") 
mobileNet_nadam = pd.read_csv("./transfer_learning_deepCNN/mobilenet_v2/training_progress_100epochs_nadam_frozen_full_aug.csv") 
mobileNet_SGD = pd.read_csv("./transfer_learning_deepCNN/mobilenet_v2/training_progress_100epochs_SGD_frozen_full_aug.csv")

# %%
fig.data = []

fig.add_trace(go.Scatter(x=mobileNet_adagrad["epoch"], y=mobileNet_adagrad["val_accuracy"],
                    mode='lines',
                    name='Adagrad'))
fig.add_trace(go.Scatter(x=mobileNet_adam["epoch"], y=mobileNet_adam["val_accuracy"],
                    mode='lines',
                    name='Adam'))
fig.add_trace(go.Scatter(x=mobileNet_adam_unfrozen["epoch"], y=mobileNet_adam_unfrozen["val_accuracy"],
                    mode='lines',
                    name='Adam_unfrozen'))
fig.add_trace(go.Scatter(x=mobileNet_nadam["epoch"], y=mobileNet_nadam["val_accuracy"],
                    mode='lines',
                    name='Nadam'))
fig.add_trace(go.Scatter(x=mobileNet_SGD["epoch"], y=mobileNet_SGD["val_accuracy"],
                    mode='lines',
                    name='t_SGD'))

fig.update_yaxes(range=[0, 1.05])
fig.update_layout(xaxis_showgrid=True, yaxis_showgrid=True)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='Gray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='Gray')



fig.update_layout(
                  xaxis = dict(title = 'Epoch'),
                  yaxis = dict(title = 'Validation accuracy'),
                  title={
                    'text': "Validation accuracy for different architectures",
                    'y':0.9,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    paper_bgcolor='rgba(255,255,255, 125)',
                    plot_bgcolor='rgba(250,250,250, 125)'
                  )
fig.update_layout(legend_title='<b> Optimizer: </b>')
fig.update_layout(legend=dict(x=0.5, y=1.15))

fig.update_layout(
    title={
        'text': "<b>Validation accuracy - MobileNet V2</b>",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.update_layout(
    legend=dict(orientation='h',yanchor='top',xanchor='center',
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
        bgcolor="white",
        bordercolor="Black",
        borderwidth=1
    )
)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True)

fig.show()
# Out:
# <div>
#
#
#             <div id="6a58fb6d-8b95-4bb7-8f60-4158b03f8733" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6a58fb6d-8b95-4bb7-8f60-4158b03f8733")) {
#                     Plotly.newPlot(
#                         '6a58fb6d-8b95-4bb7-8f60-4158b03f8733',
# ...

# %% [markdown]
# # CNN results

# %%
cnn1 = pd.read_csv(".\CNN_Results\Model__2020_21_01__19_15_51__321727/training_progress.csv") 
cnn2 = pd.read_csv(".\CNN_Results\Model__2020_21_01__20_56_58__410652/training_progress.csv") 
cnn3 = pd.read_csv(".\CNN_Results\Model__2020_21_01__21_51_10__363051/training_progress.csv") 
cnn4 = pd.read_csv(".\CNN_Results\Model__2020_21_01__22_07_11__157944/training_progress.csv") 
cnn5 = pd.read_csv(".\CNN_Results\Model__2020_24_01__19_55_08__633714/training_progress.csv") 

cnn1.head()
# Out:
#    epoch       loss  accuracy   val_loss  val_accuracy  \
# 0      1  10.388323   0.10250  10.098119      0.100694
# 1      2   9.841881   0.08750   9.570479      0.100694
# 2      3   9.330980   0.10500   9.078236      0.100694
# 3      4   8.854644   0.10000   8.619312      0.079861
# 4      5   8.410823   0.10125   8.191099      0.109375
#
#    sparse_categorical_crossentropy
# 0                         2.302501
# 1                         2.302531
# 2                         2.302193
# 3                         2.301860
# 4                         2.302007

# %%
fig.data = []

fig.add_trace(go.Scatter(x=cnn1["epoch"], y=cnn1["val_accuracy"],
                    mode='lines',
                    name='cnn1'))
fig.add_trace(go.Scatter(x=cnn2["epoch"], y=cnn2["val_accuracy"],
                    mode='lines',
                    name='cnn2'))
fig.add_trace(go.Scatter(x=cnn3["epoch"], y=cnn3["val_accuracy"],
                    mode='lines',
                    name='cnn3'))
fig.add_trace(go.Scatter(x=cnn4["epoch"], y=cnn4["val_accuracy"],
                    mode='lines',
                    name='cnn4'))
fig.add_trace(go.Scatter(x=cnn5["epoch"], y=cnn5["val_accuracy"],
                    mode='lines',
                    name='cnn5'))


fig.update_yaxes(range=[0, 1.05])
fig.update_layout(xaxis_showgrid=True, yaxis_showgrid=True)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='Gray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='Gray')



fig.update_layout(
                  xaxis = dict(title = 'Epoch'),
                  yaxis = dict(title = 'Validation accuracy'),
                  title={
                    'text': "Validation accuracy for different architectures",
                    'y':0.9,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    paper_bgcolor='rgba(255,255,255, 125)',
                    plot_bgcolor='rgba(250,250,250, 125)'
                  )
fig.update_layout(legend_title='<b> Optimizer: </b>')
fig.update_layout(legend=dict(x=0.5, y=1.15))

fig.update_layout(
    title={
        'text': "<b>Validation accuracy - CNN</b>",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.update_layout(
    legend=dict(orientation='h',yanchor='top',xanchor='center',
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
        bgcolor="white",
        bordercolor="Black",
        borderwidth=1
    )
)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True)


fig.show()
# Out:
# <div>
#
#
#             <div id="6dcc1bc9-dd84-40c0-b762-e84dfaf51d97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6dcc1bc9-dd84-40c0-b762-e84dfaf51d97")) {
#                     Plotly.newPlot(
#                         '6dcc1bc9-dd84-40c0-b762-e84dfaf51d97',
# ...

# %%
rnn1 = pd.read_csv(".\RNN_Results\Model__2020_25_01__22_45_47__592865/training_progress.csv") 
rnn2 = pd.read_csv(".\RNN_Results\Model__2020_27_01__00_58_08__389012/training_progress.csv") 
rnn3 = pd.read_csv(".\RNN_Results\Model__2020_27_01__02_35_13__064542/training_progress.csv") 


rnn1.head()
# Out:
#   epoch               loss accuracy            val_loss val_accuracy  \
# 0     1  2.945464220046997     0.09  2.8044799433814154   0.10243055
# 1     2  2.795311803817749   0.0875   2.802162673738268   0.10243055
# 2     3  2.731675090789795   0.1025  2.6908698081970215  0.104166664
# 3     4  2.674765748977661   0.0975  2.5872334241867065   0.10243055
# 4     5   2.58166693687439  0.09375   2.620339936680264   0.10243055
#
#   sparse_categorical_crossentropy
# 0                        2.553364
# 1                       2.4763813
# 2                       2.4527397
# 3                       2.4186554
# 4                       2.3425314

# %%
fig.data = []

fig.add_trace(go.Scatter(x=rnn1["epoch"], y=rnn1["val_accuracy"],
                    mode='lines',
                    name='rnn1'))
fig.add_trace(go.Scatter(x=rnn2["epoch"], y=rnn2["val_accuracy"],
                    mode='lines',
                    name='rnn2'))
fig.add_trace(go.Scatter(x=rnn3["epoch"], y=rnn3["val_accuracy"],
                    mode='lines',
                    name='rnn3'))

fig.update_yaxes(range=[0, 1.05])
fig.update_layout(xaxis_showgrid=True, yaxis_showgrid=True)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='Gray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='Gray')



fig.update_layout(
                  xaxis = dict(title = 'Epoch'),
                  yaxis = dict(title = 'Validation accuracy'),
                  title={
                    'text': "Validation accuracy for different architectures",
                    'y':0.9,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    paper_bgcolor='rgba(255,255,255, 125)',
                    plot_bgcolor='rgba(250,250,250, 125)'
                  )
fig.update_layout(legend_title='<b> Optimizer: </b>')
fig.update_layout(legend=dict(x=0.5, y=1.15))

fig.update_layout(
    title={
        'text': "<b>Validation accuracy - RNN</b>",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.update_layout(
    legend=dict(orientation='h',yanchor='top',xanchor='center',
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
        bgcolor="white",
        bordercolor="Black",
        borderwidth=1
    )
)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True)


fig.show()
# Out:
# <div>
#
#
#             <div id="3688704c-8cce-44d8-abb1-d237e3fd9e77" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3688704c-8cce-44d8-abb1-d237e3fd9e77")) {
#                     Plotly.newPlot(
#                         '3688704c-8cce-44d8-abb1-d237e3fd9e77',
# ...

# %% [markdown]
# # Best result per architecture

# %%
inception_adagrad = pd.read_csv("./transfer_learning_deepCNN/inception_v3/training_progress_100epochs_inception_adagrad_unfrozen_full_aug.csv") 
mobileNet_adam_unfrozen = pd.read_csv("./transfer_learning_deepCNN/mobilenet_v2/training_progress_100epochs_adam_unfrozen_full_aug.csv") 
cnn4 = pd.read_csv(".\CNN_Results\Model__2020_21_01__22_07_11__157944/training_progress.csv") 
rnn2 = pd.read_csv(".\RNN_Results\Model__2020_27_01__00_58_08__389012/training_progress.csv") 

import plotly.graph_objects as go

fig.data = []

fig.add_trace(go.Scatter(x=inception_adagrad["epoch"], y=inception_adagrad["val_accuracy"],
                    mode='lines',
                    name='Inception V3'))

fig.add_trace(go.Scatter(x=mobileNet_adam_unfrozen["epoch"], y=mobileNet_adam_unfrozen["val_accuracy"],
                    mode='lines',
                    name='MobileNet V2'))

fig.add_trace(go.Scatter(x=rnn2["epoch"], y=rnn2["val_accuracy"],
                    mode='lines',
                    name='RNN'))
fig.add_trace(go.Scatter(x=cnn4["epoch"], y=cnn4["val_accuracy"],
                    mode='lines',
                    name='CNN'))

fig.update_yaxes(range=[0, 1.05])
fig.update_layout(xaxis_showgrid=True, yaxis_showgrid=True)
fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='Gray')
fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='Gray')



fig.update_layout(
                  xaxis = dict(title = 'Epoch'),
                  yaxis = dict(title = 'Validation accuracy'),
                  title={
                    'text': "Validation accuracy for different models",
                    'y':0.9,
                    'x':0.5,
                    'xanchor': 'center',
                    'yanchor': 'top'},
                    paper_bgcolor='rgba(255,255,255, 125)',
                    plot_bgcolor='rgba(250,250,250, 125)'
                  )
fig.update_layout(legend_title='<b> Model: </b>')
fig.update_layout(legend=dict(x=0.5, y=1.15))

fig.update_layout(
    title={
        'text': "<b>Validation accuracy for different models</b>",
        'y':0.95,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})

fig.update_layout(
    legend=dict(orientation='h',yanchor='top',xanchor='center',
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=12,
            color="black"
        ),
        bgcolor="white",
        bordercolor="Black",
        borderwidth=1
    )
)

fig.update_xaxes(showline=True, linewidth=1, linecolor='black', mirror=True)
fig.update_yaxes(showline=True, linewidth=1, linecolor='black', mirror=True)


fig.show()
# Out:
# <div>
#
#
#             <div id="b779e7fd-2377-44d0-928f-ec93504ace88" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b779e7fd-2377-44d0-928f-ec93504ace88")) {
#                     Plotly.newPlot(
#                         'b779e7fd-2377-44d0-928f-ec93504ace88',
# ...
