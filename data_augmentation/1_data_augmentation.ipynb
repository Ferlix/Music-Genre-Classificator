# %% [markdown]
# # 1. Setup libraries

# %%
import librosa
import os
import numpy as np
import glob
from glob import iglob
import matplotlib.pyplot as plt
import librosa.display
import random
from pydub import AudioSegment
# Out:
# c:\users\federico\appdata\local\programs\python\python37\lib\site-packages\pydub\utils.py:165: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %% [markdown]
# # 3. Split in training data and test data

# %%
data_path = "../data/genres/**"
save_path_train = "../data/genres_train/"
save_path_test = "../data/genres_test/"


random.seed(1)


# Create target directory & all intermediate directories if don't exists
try:
    os.makedirs(save_path_train)    
    print("Directory " , save_path_train ,  " Created ")
except FileExistsError:
    pass

try:
    os.makedirs(save_path_test)    
    print("Directory " , save_path_test ,  " Created ")
except FileExistsError:
    pass


strings = list()

#get files names
for folderGenre in glob.iglob(data_path, recursive=True):
    if not os.path.isfile(folderGenre):
        #print(folderGenre)
        strings = list()
        for filename in glob.iglob(folderGenre + "/*", recursive=True):
            if  os.path.isfile(filename):
                #print(filename)
                strings.append(filename)
                
        random.shuffle(strings)
        #print(range(int(len(strings) / 100 * 20)))
        
        for filenumber in range(int(len(strings) / 100 * 20)):
            file = strings[filenumber]
            genre = file.split('\\')[1] #Get the genres folder
            name = file.split('\\')[2]
            number = name.split('.')[1]

            audio = AudioSegment.from_wav(file)
            try:
                os.makedirs(save_path_test + genre)    
                print("Directory " , save_path_test  + genre,  " Created ")
            except FileExistsError:
                pass

            audio.export(save_path_test + genre + "\\" + name, format="wav")

        for filenumber in range(int(len(strings) / 100 * 20), len(strings)):
            file = strings[filenumber]
            genre = file.split('\\')[1] #Get the genres folder
            name = file.split('\\')[2]
            number = name.split('.')[1]

            audio = AudioSegment.from_wav(file)
            try:
                os.makedirs(save_path_train + genre)    
                print("Directory " , save_path_train  + genre,  " Created ")
            except FileExistsError:
                pass

            audio.export(save_path_train + genre + "\\" + name, format="wav")
# Out:
# Directory  ../data/genres_train/  Created
# Directory  ../data/genres_test/  Created
# Directory  ../data/genres_test/blues  Created
# Directory  ../data/genres_train/blues  Created
# Directory  ../data/genres_test/classical  Created
# Directory  ../data/genres_train/classical  Created
# Directory  ../data/genres_test/country  Created
# Directory  ../data/genres_train/country  Created
# Directory  ../data/genres_test/disco  Created
# Directory  ../data/genres_train/disco  Created
# Directory  ../data/genres_test/hiphop  Created
# Directory  ../data/genres_train/hiphop  Created
# Directory  ../data/genres_test/jazz  Created
# Directory  ../data/genres_train/jazz  Created
# Directory  ../data/genres_test/metal  Created
# Directory  ../data/genres_train/metal  Created
# Directory  ../data/genres_test/pop  Created
# Directory  ../data/genres_train/pop  Created
# Directory  ../data/genres_test/reggae  Created
# Directory  ../data/genres_train/reggae  Created
# Directory  ../data/genres_test/rock  Created
# Directory  ../data/genres_train/rock  Created

# %% [markdown]
# # 2. Split sound files

# %%
rootdir_glob = "../data/genres_train/**"
save_path = "../data/genres_split_train/"

# Create target directory & all intermediate directories if don't exists
try:
    os.makedirs(save_path)    
    print("Directory " , save_path ,  " Created ")
except FileExistsError:
    pass

for filename in glob.iglob(rootdir_glob, recursive=True):
    if os.path.isfile(filename):
        save_folder = filename.split('\\')[1] #Get the genres folder
        name = filename.split('\\')[2]
        
        number = name.split('.')[1]
        genre = name.split('.')[0]
        
            # Create target directory & all intermediate directories if don't exists
        try:
            os.makedirs(save_path + genre)    
            print("Directory " , save_path + genre ,  " Created ")
        except FileExistsError:
            pass
        
        t1 = 0 * 1000 #Works in milliseconds
        t2 = 10 * 1000
        newAudio = AudioSegment.from_wav(filename)
        newAudio = newAudio[t1:t2]
        newAudio.export(save_path + genre + "\\" "1_" + name, format="wav")
        
        t1 = 10 * 1000 #Works in milliseconds
        t2 = 20 * 1000
        newAudio = AudioSegment.from_wav(filename)
        newAudio = newAudio[t1:t2]
        newAudio.export(save_path + genre + "\\" "2_" + name, format="wav")
        
        t1 = 20 * 1000 #Works in milliseconds
        t2 = 30 * 1000
        newAudio = AudioSegment.from_wav(filename)
        newAudio = newAudio[t1:t2]
        newAudio.export(save_path + genre + "\\" + "3_" + name, format="wav")
# Out:
# Directory  ../data/genres_split_train/  Created
# Directory  ../data/genres_split_train/blues  Created
# Directory  ../data/genres_split_train/classical  Created
# Directory  ../data/genres_split_train/country  Created
# Directory  ../data/genres_split_train/disco  Created
# Directory  ../data/genres_split_train/hiphop  Created
# Directory  ../data/genres_split_train/jazz  Created
# Directory  ../data/genres_split_train/metal  Created
# Directory  ../data/genres_split_train/pop  Created
# Directory  ../data/genres_split_train/reggae  Created
# Directory  ../data/genres_split_train/rock  Created

# %% [markdown]
# # 4. Define augmentation functions and path to folders

# %%
n_songs = 100
rootdir_glob =  "../data/genres_split_train/**"
save_path = "../data/genres_split_train_aug/"

try:
    os.makedirs(save_path)    
    print("Directory " , save_path ,  " Created ")
except FileExistsError:
    pass

def manipulate(data, noise_factor):
    noise = np.random.randn(len(data))
    augmented_data = data + noise_factor * noise
    # Cast back to same data type
    augmented_data = augmented_data.astype(type(data[0]))
    return augmented_data

def shift(data, sampling_rate, shift_max, shift_direction):
    shift = sampling_rate*shift_max
    shift_data = [0]*shift
    if shift_direction == 'right':
        shift = -shift
    elif shift_direction == 'both':
        direction = np.random.randint(0, 2)
        if direction == 1:
            shift = -shift
    augmented_data = np.roll(data, shift)
    # Set to silence for heading/ tailing
    if shift > 0:
        augmented_data=np.concatenate((augmented_data, shift_data), axis=0)
    else:
        augmented_data = np.concatenate((shift_data,augmented_data),axis=0)
    return augmented_data

def pitch_shift(data, sampling_rate, pitch_factor):
    return librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)

def speed_change(data, speed_factor,sampleRate):
    data = librosa.effects.time_stretch(data, speed_factor)
    data = shift(data,sampleRate,5,'both') #Shifting the song to make it 30 secs long.
    return data
# Out:
# Directory  ../data/genres_split_train_aug/  Created

# %% [markdown]
# # 5. Augment data
#
# ## Remember to split the train and test dataset before this step, and do the augmentation ONLY on the training data!

# %% [markdown]
# Augmentation chosen:
#     - add noise
#     - add more noise
#     - change pitch
#     - speed up
#     - speed down
#
# After augmenting, the dataset will be 6 times larger

# %%
count = 0
for filename in glob.iglob(rootdir_glob, recursive=True):
    if os.path.isfile(filename):
        x, sampleRate = librosa.load(filename, duration=30)
        save_folder = filename.split('\\')[1] #Get the genres folder
        name = filename.split('\\')[2]
        
        try:
            os.makedirs(save_path + save_folder)    
            print("Directory " ,save_path + save_folder ,  " Created ")
        except FileExistsError:
            pass
        
        save_fileName = save_path  + save_folder + "/" + "original_" + name
        librosa.output.write_wav(save_fileName, x, sampleRate)
        
        # add noise
        noise_factor = np.random.normal(0,2)/100
        augment_data = manipulate(x,noise_factor)
        save_fileName = save_path  + save_folder + "/" + "aug1_" + name
        librosa.output.write_wav(save_fileName , augment_data, sampleRate)
        
        # add MORE noise!
        noise_factor = np.random.normal(2,4)/100
        augment_data = manipulate(x,noise_factor)
        save_fileName = save_path  + save_folder + "/" + "aug2_" + name
        librosa.output.write_wav(save_fileName , augment_data, sampleRate)

        #change pitch a bit
        pitch_factor = np.random.normal(0,2)/100
        augment_data = pitch_shift(x,sampleRate,pitch_factor)
        save_fileName = save_path  + save_folder + "/" + "aug3_" + name
        librosa.output.write_wav(save_fileName, augment_data, sampleRate)



        count = count + 1
        if(count % 10 == 0):
            print("Completed ",count," songs Augmentation")
print("Done...")
# Out:
# Directory  ../data/genres_split_train_aug/blues  Created
# Completed  10  songs Augmentation
# Completed  20  songs Augmentation
# Completed  30  songs Augmentation
# Completed  40  songs Augmentation
# Completed  50  songs Augmentation
# Completed  60  songs Augmentation
# Completed  70  songs Augmentation
# Completed  80  songs Augmentation
# Completed  90  songs Augmentation
# Completed  100  songs Augmentation
# Completed  110  songs Augmentation
# Completed  120  songs Augmentation
# Completed  130  songs Augmentation
# Completed  140  songs Augmentation
# Completed  150  songs Augmentation
# Completed  160  songs Augmentation
# Completed  170  songs Augmentation
# Completed  180  songs Augmentation
# Completed  190  songs Augmentation
# Completed  200  songs Augmentation
# Completed  210  songs Augmentation
# Completed  220  songs Augmentation
# Completed  230  songs Augmentation
# Completed  240  songs Augmentation
# Directory  ../data/genres_split_train_aug/classical  Created
# Completed  250  songs Augmentation
# Completed  260  songs Augmentation
# Completed  270  songs Augmentation
# Completed  280  songs Augmentation
# Completed  290  songs Augmentation
# Completed  300  songs Augmentation
# Completed  310  songs Augmentation
# Completed  320  songs Augmentation
# Completed  330  songs Augmentation
# Completed  340  songs Augmentation
# Completed  350  songs Augmentation
# Completed  360  songs Augmentation
# Completed  370  songs Augmentation
# Completed  380  songs Augmentation
# Completed  390  songs Augmentation
# Completed  400  songs Augmentation
# Completed  410  songs Augmentation
# Completed  420  songs Augmentation
# Completed  430  songs Augmentation
# Completed  440  songs Augmentation
# Completed  450  songs Augmentation
# Completed  460  songs Augmentation
# Completed  470  songs Augmentation
# Completed  480  songs Augmentation
# Directory  ../data/genres_split_train_aug/country  Created
# Completed  490  songs Augmentation
# Completed  500  songs Augmentation
# Completed  510  songs Augmentation
# Completed  520  songs Augmentation
# Completed  530  songs Augmentation
# Completed  540  songs Augmentation
# Completed  550  songs Augmentation
# Completed  560  songs Augmentation
# Completed  570  songs Augmentation
# Completed  580  songs Augmentation
# Completed  590  songs Augmentation
# Completed  600  songs Augmentation
# Completed  610  songs Augmentation
# Completed  620  songs Augmentation
# Completed  630  songs Augmentation
# Completed  640  songs Augmentation
# Completed  650  songs Augmentation
# Completed  660  songs Augmentation
# Completed  670  songs Augmentation
# Completed  680  songs Augmentation
# Completed  690  songs Augmentation
# Completed  700  songs Augmentation
# Completed  710  songs Augmentation
# Completed  720  songs Augmentation
# Directory  ../data/genres_split_train_aug/disco  Created
# Completed  730  songs Augmentation
# Completed  740  songs Augmentation
# Completed  750  songs Augmentation
# Completed  760  songs Augmentation
# Completed  770  songs Augmentation
# Completed  780  songs Augmentation
# Completed  790  songs Augmentation
# Completed  800  songs Augmentation
# Completed  810  songs Augmentation
# Completed  820  songs Augmentation
# Completed  830  songs Augmentation
# Completed  840  songs Augmentation
# Completed  850  songs Augmentation
# Completed  860  songs Augmentation
# Completed  870  songs Augmentation
# Completed  880  songs Augmentation
# Completed  890  songs Augmentation
# Completed  900  songs Augmentation
# Completed  910  songs Augmentation
# Completed  920  songs Augmentation
# Completed  930  songs Augmentation
# Completed  940  songs Augmentation
# Completed  950  songs Augmentation
# Completed  960  songs Augmentation
# Directory  ../data/genres_split_train_aug/hiphop  Created
# Completed  970  songs Augmentation
# Completed  980  songs Augmentation
# Completed  990  songs Augmentation
# Completed  1000  songs Augmentation
# Completed  1010  songs Augmentation
# Completed  1020  songs Augmentation
# Completed  1030  songs Augmentation
# Completed  1040  songs Augmentation
# Completed  1050  songs Augmentation
# Completed  1060  songs Augmentation
# Completed  1070  songs Augmentation
# Completed  1080  songs Augmentation
# Completed  1090  songs Augmentation
# Completed  1100  songs Augmentation
# Completed  1110  songs Augmentation
# Completed  1120  songs Augmentation
# Completed  1130  songs Augmentation
# Completed  1140  songs Augmentation
# Completed  1150  songs Augmentation
# Completed  1160  songs Augmentation
# Completed  1170  songs Augmentation
# Completed  1180  songs Augmentation
# Completed  1190  songs Augmentation
# Completed  1200  songs Augmentation
# Directory  ../data/genres_split_train_aug/jazz  Created
# Completed  1210  songs Augmentation
# Completed  1220  songs Augmentation
# Completed  1230  songs Augmentation
# Completed  1240  songs Augmentation
# Completed  1250  songs Augmentation
# Completed  1260  songs Augmentation
# Completed  1270  songs Augmentation
# Completed  1280  songs Augmentation
# Completed  1290  songs Augmentation
# Completed  1300  songs Augmentation
# Completed  1310  songs Augmentation
# Completed  1320  songs Augmentation
# Completed  1330  songs Augmentation
# Completed  1340  songs Augmentation
# Completed  1350  songs Augmentation
# Completed  1360  songs Augmentation
# Completed  1370  songs Augmentation
# Completed  1380  songs Augmentation
# Completed  1390  songs Augmentation
# Completed  1400  songs Augmentation
# Completed  1410  songs Augmentation
# Completed  1420  songs Augmentation
# Completed  1430  songs Augmentation
# Completed  1440  songs Augmentation
# Directory  ../data/genres_split_train_aug/metal  Created
# Completed  1450  songs Augmentation
# Completed  1460  songs Augmentation
# Completed  1470  songs Augmentation
# Completed  1480  songs Augmentation
# Completed  1490  songs Augmentation
# Completed  1500  songs Augmentation
# Completed  1510  songs Augmentation
# Completed  1520  songs Augmentation
# Completed  1530  songs Augmentation
# Completed  1540  songs Augmentation
# Completed  1550  songs Augmentation
# Completed  1560  songs Augmentation
# Completed  1570  songs Augmentation
# Completed  1580  songs Augmentation
# Completed  1590  songs Augmentation
# Completed  1600  songs Augmentation
# Completed  1610  songs Augmentation
# Completed  1620  songs Augmentation
# Completed  1630  songs Augmentation
# Completed  1640  songs Augmentation
# Completed  1650  songs Augmentation
# Completed  1660  songs Augmentation
# Completed  1670  songs Augmentation
# Completed  1680  songs Augmentation
# Directory  ../data/genres_split_train_aug/pop  Created
# Completed  1690  songs Augmentation
# Completed  1700  songs Augmentation
# Completed  1710  songs Augmentation
# Completed  1720  songs Augmentation
# Completed  1730  songs Augmentation
# Completed  1740  songs Augmentation
# Completed  1750  songs Augmentation
# Completed  1760  songs Augmentation
# Completed  1770  songs Augmentation
# Completed  1780  songs Augmentation
# Completed  1790  songs Augmentation
# Completed  1800  songs Augmentation
# Completed  1810  songs Augmentation
# Completed  1820  songs Augmentation
# Completed  1830  songs Augmentation
# Completed  1840  songs Augmentation
# Completed  1850  songs Augmentation
# Completed  1860  songs Augmentation
# Completed  1870  songs Augmentation
# Completed  1880  songs Augmentation
# Completed  1890  songs Augmentation
# Completed  1900  songs Augmentation
# Completed  1910  songs Augmentation
# Completed  1920  songs Augmentation
# Directory  ../data/genres_split_train_aug/reggae  Created
# Completed  1930  songs Augmentation
# Completed  1940  songs Augmentation
# Completed  1950  songs Augmentation
# Completed  1960  songs Augmentation
# Completed  1970  songs Augmentation
# Completed  1980  songs Augmentation
# Completed  1990  songs Augmentation
# Completed  2000  songs Augmentation
# Completed  2010  songs Augmentation
# Completed  2020  songs Augmentation
# Completed  2030  songs Augmentation
# Completed  2040  songs Augmentation
# Completed  2050  songs Augmentation
# Completed  2060  songs Augmentation
# Completed  2070  songs Augmentation
# Completed  2080  songs Augmentation
# Completed  2090  songs Augmentation
# Completed  2100  songs Augmentation
# Completed  2110  songs Augmentation
# Completed  2120  songs Augmentation
# Completed  2130  songs Augmentation
# Completed  2140  songs Augmentation
# Completed  2150  songs Augmentation
# Completed  2160  songs Augmentation
# Directory  ../data/genres_split_train_aug/rock  Created
# Completed  2170  songs Augmentation
# Completed  2180  songs Augmentation
# Completed  2190  songs Augmentation
# Completed  2200  songs Augmentation
# Completed  2210  songs Augmentation
# Completed  2220  songs Augmentation
# Completed  2230  songs Augmentation
# Completed  2240  songs Augmentation
# Completed  2250  songs Augmentation
# Completed  2260  songs Augmentation
# Completed  2270  songs Augmentation
# Completed  2280  songs Augmentation
# Completed  2290  songs Augmentation
# Completed  2300  songs Augmentation
# Completed  2310  songs Augmentation
# Completed  2320  songs Augmentation
# Completed  2330  songs Augmentation
# Completed  2340  songs Augmentation
# Completed  2350  songs Augmentation
# Completed  2360  songs Augmentation
# Completed  2370  songs Augmentation
# Completed  2380  songs Augmentation
# Completed  2390  songs Augmentation
# Completed  2400  songs Augmentation
# Done...
