# %% [markdown]
# # 1. Import libraries

# %%
import librosa #If you receive an error with librosa.load, you may need to install ffmpeg.
import os
import numpy as np
from glob import iglob
import matplotlib.pyplot as plt
import librosa.display

# %% [markdown]
# # 2. Load some songs

# %%
n_songs = 9                            # number of songs
rootdir_glob = "../data/genres/**"     # path to songs


# This will return a matrix with all the songs, one per row
# (100 songs per genre in alphabetical order, 10 genres)
samplingRates= np.zeros((0,1))
songs = np.zeros((0,661500))

for filename in glob.iglob(rootdir_glob, recursive=True):
    if os.path.isfile(filename): # filter dirs
        x, sampleRate = librosa.load(filename, duration = 30)
        songs = np.vstack( [songs, x] )
        if(len(songs[:]) > n_songs):
            break
print('Done importing songs')
# Out:
# Done importing songs

# %% [markdown]
# # 3. Show waveforms

# %%
plt.figure(figsize=(15, 15))
for i in range(1, len(songs[:])):
    plt.subplot(3, 3, i)
    librosa.display.waveplot(songs[i], sr=sr)

# %% [markdown]
# # 4. Show spectograms

# %%
plt.figure(figsize=(15, 15))
path_save = "../data/genres/spectrograms"

for i in range(1, len(songs[:])):
    plt.subplot(3, 3, i)
    X = librosa.stft(songs[i])
    Xdb = librosa.amplitude_to_db(abs(X))
    librosa.display.specshow(Xdb, sr=sr,  cmap='plasma', x_axis='time', y_axis='mel')

# %% [markdown]
# # 5. Preprocess all data and save spectrograms

# %%
rootdir_glob = "../data/genres/**"
path_save = "../data/spectrograms/"


i = 0
for filename in glob.iglob(rootdir_glob, recursive=True):
    if os.path.isfile(filename): # filter dirs
        x, sampleRate = librosa.load(filename, duration = 30)
        fig = plt.figure(figsize=(9, 9), frameon=False)
        ax = plt.Axes(fig, [0., 0., 1., 1.])
        ax.set_axis_off()
        fig.add_axes(ax)
        X = librosa.stft(x)
        Xdb = librosa.amplitude_to_db(abs(X))
        librosa.display.specshow(Xdb, sr=sr,  cmap='plasma', x_axis='time', y_axis='mel')
        plt.savefig(path_save + 'spectrogram_'+ str("{:04d}".format(i)) + '.png',  transparent=True, pad_inches=0.0)
        plt.close(fig)
        i = i + 1

print('Conversion to spectograms complete.')
print('Converted songs: ' + str(i))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-302-6d1c1ec8a51c> in <module>
#      14         Xdb = librosa.amplitude_to_db(abs(X))
#      15         librosa.display.specshow(Xdb, sr=sr,  cmap='plasma', x_axis='time', y_axis='mel')
# ---> 16         plt.savefig(path_save + 'spectrogram_'+ str("{:04d}".format(i)) + '.png',  transparent=True, pad_inches=0.0)
#      17         plt.close(fig)
#      18         i = i + 1
#
# c:\users\federico\appdata\local\programs\python\python37\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     721     fig = gcf()
#     722     res = fig.savefig(*args, **kwargs)
# --> 723     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     724     return res
#     725
#
# ...

# %% [markdown]
# # 6. Create labels

# %%
path_save = "../data/"

labels = np.repeat(range(10), 100)
labels = labels.astype(np.int64)
np.savetxt(path_save + "labels.txt", labels, fmt="%d")
